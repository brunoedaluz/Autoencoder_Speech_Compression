# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display
import IPython.display as ipd
import keras
from keras import layers
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler
import os
from glob import glob

# %%
# !pip install pesq
from pesq import pesq
# Out:
# Collecting pesq
#   Downloading pesq-0.0.3.tar.gz (35 kB)
# Building wheels for collected packages: pesq
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.3-cp37-cp37m-linux_x86_64.whl size=209961 sha256=c727464a15d65d5558ecccc19007bcccdccdfbe99ebe8a79c5a04915b2d04169
#   Stored in directory: /root/.cache/pip/wheels/4f/67/5b/aa7cf31fe0c7199e35c604bb7bc91c629a13726bf221fedba0
# Successfully built pesq
# Installing collected packages: pesq
# Successfully installed pesq-0.0.3

# %% [markdown]
# # Load Audio Files

# %%
audio_files_train = [y for x in os.walk("Librispeech/dev-clean") for y in glob(os.path.join(x[0], '*.flac'))]

print("Total .flac files: " + str(len(audio_files_train)))

audio_inputs_train = []

for f in audio_files_train:
    try:
        audio, sr = librosa.load(f, sr=16000, duration = 8)
        if(len(audio) == 128000):
            audio_inputs_train.append(audio)
    except:
        pass

print("Total used files: " + str(len(audio_inputs_train)))
# Out:
# Total de arquivos .flac: 3317

# %%
audio_files_test = [y for x in os.walk("Librispeech/test-clean") for y in glob(os.path.join(x[0], '*.flac'))]

print("Total .flac files: " + str(len(audio_files_test)))

audio_inputs_test = []

for f in audio_files_test:
    try:
        audio, sr = librosa.load(f, sr=16000, duration = 8)
        if(len(audio) == 128000):
            audio_inputs_test.append(audio)
    except:
        pass

print("Total used files: " + str(len(audio_inputs_test)))
# Out:
# Total de arquivos .flac: 2620
# Total de arquivos de áudio utilizados: 859

# %% [markdown]
# # Constants

# %%
hop_length = 128
n_fft = 512

# %% [markdown]
# # Training Data

# %%
x_train = []

for elem in audio_inputs_train:
    stft = librosa.stft(elem, n_fft=n_fft, hop_length=hop_length, window='hann')
    x_train.append(np.abs(stft[0:256,0:1000]))
    
x_train = np.stack(x_train)

x_train.shape
# Out:
# (1644, 256, 1000)

# %% [markdown]
# # Test Data

# %%
x_test = []
x_test_phase = []

for elem in audio_inputs_test:
    stft = librosa.stft(elem, n_fft=n_fft, hop_length=hop_length, window='hann')
    x_test_phase.append(np.angle(stft))
    x_test.append(np.abs(stft[0:256,0:1000]))
    
x_test = np.stack(x_test)

x_test_phase = np.stack(x_test_phase)

x_test.shape
# Out:
# (859, 256, 1000)

# %% [markdown]
# # Scaling Data

# %%
#Train Data
scaler_train = StandardScaler()

X_train_scaled = []

for elem in x_train:  
    X_train_scaled.append(scaler_train.fit_transform(elem))

X_train_scaled = np.stack(X_train_scaled)

X_train_scaled = X_train_scaled.reshape((-1, X_train_scaled.shape[1], X_train_scaled.shape[2], 1))

# %%
#Test Data
scaler_test = StandardScaler()

X_test_scaled = []

for elem in x_test:  
    X_test_scaled.append(scaler_test.fit_transform(elem))

X_test_scaled = np.stack(X_test_scaled)

X_test_scaled = X_test_scaled.reshape((-1, X_test_scaled.shape[1], X_test_scaled.shape[2], 1))

# %% [markdown]
# # Convolutional Network

# %%
#Callbacks

earlystop = keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")

callbacks = [earlystop]

# %%
#Convolutional Autoencoder

input = keras.Input(shape=(X_train_scaled.shape[1], X_train_scaled.shape[2],X_train_scaled.shape[3]))

#Encoder
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

#Decoder
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

conv_autoencoder = keras.Model(input, decoded)
conv_autoencoder.compile(optimizer='adam', loss='mse')
conv_autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 1000, 1)]    0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 1000, 16)     160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 500, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 500, 8)       1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 250, 8)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 250, 8)        584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 125, 8)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 125, 8)        584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 64, 250, 8)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 250, 8)        584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 128, 500, 8)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 500, 16)      1168
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 256, 1000, 16)     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 256, 1000, 1)      145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the Model

# %%
#Training

history = conv_autoencoder.fit(
    X_train_scaled,
    X_train_scaled,
    epochs=500,
    batch_size=32,
    validation_split=0.15,
    callbacks=[
        callbacks
    ]
)
# Out:
# Epoch 1/500
# 44/44 [==============================] - 55s 537ms/step - loss: 0.9297 - val_loss: 0.7481
# Epoch 2/500
# 44/44 [==============================] - 19s 425ms/step - loss: 0.7432 - val_loss: 0.7276
# Epoch 3/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.7308 - val_loss: 0.7202
# Epoch 4/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.7255 - val_loss: 0.7162
# Epoch 5/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7222 - val_loss: 0.7133
# Epoch 6/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7198 - val_loss: 0.7110
# Epoch 7/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7178 - val_loss: 0.7092
# Epoch 8/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7162 - val_loss: 0.7078
# Epoch 9/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7150 - val_loss: 0.7067
# Epoch 10/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7140 - val_loss: 0.7059
# Epoch 11/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7132 - val_loss: 0.7051
# Epoch 12/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7125 - val_loss: 0.7046
# Epoch 13/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7119 - val_loss: 0.7039
# Epoch 14/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7113 - val_loss: 0.7035
# Epoch 15/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7108 - val_loss: 0.7033
# Epoch 16/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7104 - val_loss: 0.7025
# Epoch 17/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7101 - val_loss: 0.7023
# Epoch 18/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7096 - val_loss: 0.7019
# Epoch 19/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7093 - val_loss: 0.7016
# Epoch 20/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7090 - val_loss: 0.7013
# Epoch 21/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7087 - val_loss: 0.7011
# Epoch 22/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7084 - val_loss: 0.7007
# Epoch 23/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7081 - val_loss: 0.7005
# Epoch 24/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7079 - val_loss: 0.7003
# Epoch 25/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7076 - val_loss: 0.7000
# Epoch 26/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7073 - val_loss: 0.7000
# Epoch 27/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7071 - val_loss: 0.6995
# Epoch 28/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7067 - val_loss: 0.6992
# Epoch 29/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7065 - val_loss: 0.6991
# Epoch 30/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7062 - val_loss: 0.6987
# Epoch 31/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7060 - val_loss: 0.6985
# Epoch 32/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.7057 - val_loss: 0.6983
# Epoch 33/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7054 - val_loss: 0.6981
# Epoch 34/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7052 - val_loss: 0.6978
# Epoch 35/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7049 - val_loss: 0.6976
# Epoch 36/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7047 - val_loss: 0.6974
# Epoch 37/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7044 - val_loss: 0.6972
# Epoch 38/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7042 - val_loss: 0.6970
# Epoch 39/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7039 - val_loss: 0.6967
# Epoch 40/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7037 - val_loss: 0.6965
# Epoch 41/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7035 - val_loss: 0.6963
# Epoch 42/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7033 - val_loss: 0.6961
# Epoch 43/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7030 - val_loss: 0.6961
# Epoch 44/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7028 - val_loss: 0.6957
# Epoch 45/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7026 - val_loss: 0.6955
# Epoch 46/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7024 - val_loss: 0.6953
# Epoch 47/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7021 - val_loss: 0.6951
# Epoch 48/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7019 - val_loss: 0.6948
# Epoch 49/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7017 - val_loss: 0.6946
# Epoch 50/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7014 - val_loss: 0.6943
# Epoch 51/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.7010 - val_loss: 0.6940
# Epoch 52/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7008 - val_loss: 0.6937
# Epoch 53/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.7003 - val_loss: 0.6933
# Epoch 54/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.7000 - val_loss: 0.6932
# Epoch 55/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6997 - val_loss: 0.6927
# Epoch 56/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6993 - val_loss: 0.6928
# Epoch 57/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6990 - val_loss: 0.6921
# Epoch 58/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6987 - val_loss: 0.6920
# Epoch 59/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6985 - val_loss: 0.6921
# Epoch 60/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6982 - val_loss: 0.6914
# Epoch 61/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6980 - val_loss: 0.6913
# Epoch 62/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6978 - val_loss: 0.6910
# Epoch 63/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6975 - val_loss: 0.6908
# Epoch 64/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6974 - val_loss: 0.6907
# Epoch 65/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6971 - val_loss: 0.6905
# Epoch 66/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6970 - val_loss: 0.6903
# Epoch 67/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6968 - val_loss: 0.6902
# Epoch 68/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6966 - val_loss: 0.6900
# Epoch 69/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6965 - val_loss: 0.6899
# Epoch 70/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6963 - val_loss: 0.6898
# Epoch 71/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6962 - val_loss: 0.6896
# Epoch 72/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6960 - val_loss: 0.6896
# Epoch 73/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6958 - val_loss: 0.6894
# Epoch 74/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6957 - val_loss: 0.6894
# Epoch 75/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6957 - val_loss: 0.6891
# Epoch 76/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6954 - val_loss: 0.6890
# Epoch 77/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6953 - val_loss: 0.6889
# Epoch 78/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6953 - val_loss: 0.6891
# Epoch 79/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6952 - val_loss: 0.6887
# Epoch 80/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6950 - val_loss: 0.6887
# Epoch 81/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6949 - val_loss: 0.6886
# Epoch 82/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6948 - val_loss: 0.6888
# Epoch 83/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6949 - val_loss: 0.6884
# Epoch 84/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6947 - val_loss: 0.6889
# Epoch 85/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6946 - val_loss: 0.6883
# Epoch 86/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6945 - val_loss: 0.6882
# Epoch 87/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6945 - val_loss: 0.6884
# Epoch 88/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6944 - val_loss: 0.6880
# Epoch 89/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6943 - val_loss: 0.6880
# Epoch 90/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6942 - val_loss: 0.6880
# Epoch 91/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6941 - val_loss: 0.6878
# Epoch 92/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6941 - val_loss: 0.6879
# Epoch 93/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6940 - val_loss: 0.6877
# Epoch 94/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6940 - val_loss: 0.6880
# Epoch 95/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6939 - val_loss: 0.6876
# Epoch 96/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6939 - val_loss: 0.6876
# Epoch 97/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6938 - val_loss: 0.6878
# Epoch 98/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6937 - val_loss: 0.6875
# Epoch 99/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6937 - val_loss: 0.6875
# Epoch 100/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6936 - val_loss: 0.6875
# Epoch 101/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6935 - val_loss: 0.6875
# Epoch 102/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6935 - val_loss: 0.6873
# Epoch 103/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6934 - val_loss: 0.6873
# Epoch 104/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6933 - val_loss: 0.6872
# Epoch 105/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6933 - val_loss: 0.6871
# Epoch 106/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6933 - val_loss: 0.6871
# Epoch 107/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6932 - val_loss: 0.6871
# Epoch 108/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6931 - val_loss: 0.6870
# Epoch 109/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6931 - val_loss: 0.6870
# Epoch 110/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6930 - val_loss: 0.6869
# Epoch 111/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6931 - val_loss: 0.6868
# Epoch 112/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6930 - val_loss: 0.6868
# Epoch 113/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6929 - val_loss: 0.6868
# Epoch 114/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6929 - val_loss: 0.6867
# Epoch 115/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6928 - val_loss: 0.6870
# Epoch 116/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6929 - val_loss: 0.6867
# Epoch 117/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6928 - val_loss: 0.6868
# Epoch 118/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6927 - val_loss: 0.6866
# Epoch 119/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6926 - val_loss: 0.6865
# Epoch 120/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6927 - val_loss: 0.6865
# Epoch 121/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6926 - val_loss: 0.6864
# Epoch 122/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6925 - val_loss: 0.6864
# Epoch 123/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6925 - val_loss: 0.6865
# Epoch 124/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6924 - val_loss: 0.6864
# Epoch 125/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6924 - val_loss: 0.6864
# Epoch 126/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6924 - val_loss: 0.6863
# Epoch 127/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6923 - val_loss: 0.6864
# Epoch 128/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6923 - val_loss: 0.6863
# Epoch 129/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6923 - val_loss: 0.6862
# Epoch 130/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6922 - val_loss: 0.6861
# Epoch 131/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6922 - val_loss: 0.6861
# Epoch 132/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6921 - val_loss: 0.6861
# Epoch 133/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6921 - val_loss: 0.6860
# Epoch 134/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6922 - val_loss: 0.6861
# Epoch 135/500
# 44/44 [==============================] - 19s 431ms/step - loss: 0.6921 - val_loss: 0.6861
# Epoch 136/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6921 - val_loss: 0.6860
# Epoch 137/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6920 - val_loss: 0.6860
# Epoch 138/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6919 - val_loss: 0.6860
# Epoch 139/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6919 - val_loss: 0.6862
# Epoch 140/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6919 - val_loss: 0.6858
# Epoch 141/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6918 - val_loss: 0.6858
# Epoch 142/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6918 - val_loss: 0.6858
# Epoch 143/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6918 - val_loss: 0.6858
# Epoch 144/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6918 - val_loss: 0.6858
# Epoch 145/500
# 44/44 [==============================] - 19s 431ms/step - loss: 0.6917 - val_loss: 0.6860
# Epoch 146/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6919 - val_loss: 0.6857
# Epoch 147/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6917 - val_loss: 0.6857
# Epoch 148/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6916 - val_loss: 0.6856
# Epoch 149/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6916 - val_loss: 0.6856
# Epoch 150/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6916 - val_loss: 0.6858
# Epoch 151/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6916 - val_loss: 0.6856
# Epoch 152/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6916 - val_loss: 0.6856
# Epoch 153/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6915 - val_loss: 0.6855
# Epoch 154/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6915 - val_loss: 0.6855
# Epoch 155/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6915 - val_loss: 0.6855
# Epoch 156/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6915 - val_loss: 0.6854
# Epoch 157/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6914 - val_loss: 0.6855
# Epoch 158/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6914 - val_loss: 0.6853
# Epoch 159/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6914 - val_loss: 0.6853
# Epoch 160/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6913 - val_loss: 0.6853
# Epoch 161/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6913 - val_loss: 0.6856
# Epoch 162/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6913 - val_loss: 0.6853
# Epoch 163/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6912 - val_loss: 0.6852
# Epoch 164/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6912 - val_loss: 0.6852
# Epoch 165/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6914 - val_loss: 0.6852
# Epoch 166/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6911 - val_loss: 0.6851
# Epoch 167/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6911 - val_loss: 0.6851
# Epoch 168/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6911 - val_loss: 0.6851
# Epoch 169/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6910 - val_loss: 0.6851
# Epoch 170/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6912 - val_loss: 0.6852
# Epoch 171/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6910 - val_loss: 0.6850
# Epoch 172/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6910 - val_loss: 0.6851
# Epoch 173/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6911 - val_loss: 0.6850
# Epoch 174/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6909 - val_loss: 0.6851
# Epoch 175/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6909 - val_loss: 0.6849
# Epoch 176/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6909 - val_loss: 0.6849
# Epoch 177/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6909 - val_loss: 0.6850
# Epoch 178/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6909 - val_loss: 0.6849
# Epoch 179/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6908 - val_loss: 0.6849
# Epoch 180/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6908 - val_loss: 0.6849
# Epoch 181/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6908 - val_loss: 0.6848
# Epoch 182/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6907 - val_loss: 0.6848
# Epoch 183/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6907 - val_loss: 0.6848
# Epoch 184/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6907 - val_loss: 0.6847
# Epoch 185/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6908 - val_loss: 0.6848
# Epoch 186/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6906 - val_loss: 0.6849
# Epoch 187/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6906 - val_loss: 0.6847
# Epoch 188/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6906 - val_loss: 0.6846
# Epoch 189/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6906 - val_loss: 0.6847
# Epoch 190/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6906 - val_loss: 0.6849
# Epoch 191/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6906 - val_loss: 0.6846
# Epoch 192/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6905 - val_loss: 0.6846
# Epoch 193/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6905 - val_loss: 0.6845
# Epoch 194/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6904 - val_loss: 0.6845
# Epoch 195/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6905 - val_loss: 0.6845
# Epoch 196/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6905 - val_loss: 0.6846
# Epoch 197/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6904 - val_loss: 0.6844
# Epoch 198/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6904 - val_loss: 0.6845
# Epoch 199/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6904 - val_loss: 0.6844
# Epoch 200/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6904 - val_loss: 0.6845
# Epoch 201/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6903 - val_loss: 0.6844
# Epoch 202/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6903 - val_loss: 0.6844
# Epoch 203/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6904 - val_loss: 0.6843
# Epoch 204/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6902 - val_loss: 0.6843
# Epoch 205/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6902 - val_loss: 0.6843
# Epoch 206/500
# 44/44 [==============================] - 19s 431ms/step - loss: 0.6902 - val_loss: 0.6843
# Epoch 207/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6902 - val_loss: 0.6845
# Epoch 208/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6903 - val_loss: 0.6842
# Epoch 209/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6901 - val_loss: 0.6842
# Epoch 210/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6902 - val_loss: 0.6843
# Epoch 211/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6901 - val_loss: 0.6845
# Epoch 212/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6901 - val_loss: 0.6842
# Epoch 213/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6901 - val_loss: 0.6842
# Epoch 214/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6901 - val_loss: 0.6841
# Epoch 215/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6902 - val_loss: 0.6841
# Epoch 216/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6900 - val_loss: 0.6841
# Epoch 217/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6900 - val_loss: 0.6841
# Epoch 218/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6900 - val_loss: 0.6841
# Epoch 219/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6900 - val_loss: 0.6841
# Epoch 220/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6901 - val_loss: 0.6845
# Epoch 221/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6900 - val_loss: 0.6840
# Epoch 222/500
# 44/44 [==============================] - 19s 431ms/step - loss: 0.6899 - val_loss: 0.6841
# Epoch 223/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6899 - val_loss: 0.6840
# Epoch 224/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6899 - val_loss: 0.6840
# Epoch 225/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6899 - val_loss: 0.6841
# Epoch 226/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6899 - val_loss: 0.6839
# Epoch 227/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6899 - val_loss: 0.6841
# Epoch 228/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6898 - val_loss: 0.6841
# Epoch 229/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6899 - val_loss: 0.6839
# Epoch 230/500
# 44/44 [==============================] - 19s 431ms/step - loss: 0.6899 - val_loss: 0.6840
# Epoch 231/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6898 - val_loss: 0.6839
# Epoch 232/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6898 - val_loss: 0.6839
# Epoch 233/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6897 - val_loss: 0.6839
# Epoch 234/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6897 - val_loss: 0.6838
# Epoch 235/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6897 - val_loss: 0.6838
# Epoch 236/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6898 - val_loss: 0.6838
# Epoch 237/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6897 - val_loss: 0.6838
# Epoch 238/500
# 44/44 [==============================] - 19s 431ms/step - loss: 0.6897 - val_loss: 0.6838
# Epoch 239/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6897 - val_loss: 0.6837
# Epoch 240/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6897 - val_loss: 0.6837
# Epoch 241/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6896 - val_loss: 0.6837
# Epoch 242/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6897 - val_loss: 0.6838
# Epoch 243/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6896 - val_loss: 0.6837
# Epoch 244/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6896 - val_loss: 0.6839
# Epoch 245/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6896 - val_loss: 0.6837
# Epoch 246/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6895 - val_loss: 0.6836
# Epoch 247/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6895 - val_loss: 0.6836
# Epoch 248/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6895 - val_loss: 0.6838
# Epoch 249/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6896 - val_loss: 0.6836
# Epoch 250/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6895 - val_loss: 0.6837
# Epoch 251/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6895 - val_loss: 0.6836
# Epoch 252/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6895 - val_loss: 0.6836
# Epoch 253/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6895 - val_loss: 0.6836
# Epoch 254/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6895 - val_loss: 0.6836
# Epoch 255/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6895 - val_loss: 0.6839
# Epoch 256/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6894 - val_loss: 0.6836
# Epoch 257/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6894 - val_loss: 0.6835
# Epoch 258/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6894 - val_loss: 0.6835
# Epoch 259/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6894 - val_loss: 0.6835
# Epoch 260/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6894 - val_loss: 0.6835
# Epoch 261/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6893 - val_loss: 0.6835
# Epoch 262/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6894 - val_loss: 0.6839
# Epoch 263/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6895 - val_loss: 0.6836
# Epoch 264/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6893 - val_loss: 0.6835
# Epoch 265/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6893 - val_loss: 0.6834
# Epoch 266/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6893 - val_loss: 0.6834
# Epoch 267/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6893 - val_loss: 0.6834
# Epoch 268/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6895 - val_loss: 0.6837
# Epoch 269/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6893 - val_loss: 0.6836
# Epoch 270/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6893 - val_loss: 0.6834
# Epoch 271/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6892 - val_loss: 0.6835
# Epoch 272/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6892 - val_loss: 0.6833
# Epoch 273/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6892 - val_loss: 0.6835
# Epoch 274/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6892 - val_loss: 0.6833
# Epoch 275/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6892 - val_loss: 0.6833
# Epoch 276/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6892 - val_loss: 0.6833
# Epoch 277/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6892 - val_loss: 0.6833
# Epoch 278/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6892 - val_loss: 0.6833
# Epoch 279/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6891 - val_loss: 0.6833
# Epoch 280/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6892 - val_loss: 0.6833
# Epoch 281/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6891 - val_loss: 0.6833
# Epoch 282/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6891 - val_loss: 0.6832
# Epoch 283/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6891 - val_loss: 0.6835
# Epoch 284/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6893 - val_loss: 0.6832
# Epoch 285/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6891 - val_loss: 0.6833
# Epoch 286/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6891 - val_loss: 0.6833
# Epoch 287/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6891 - val_loss: 0.6832
# Epoch 288/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6890 - val_loss: 0.6832
# Epoch 289/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6890 - val_loss: 0.6832
# Epoch 290/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6891 - val_loss: 0.6833
# Epoch 291/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6890 - val_loss: 0.6832
# Epoch 292/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6890 - val_loss: 0.6832
# Epoch 293/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6890 - val_loss: 0.6832
# Epoch 294/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6893 - val_loss: 0.6833
# Epoch 295/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6889 - val_loss: 0.6832
# Epoch 296/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6889 - val_loss: 0.6831
# Epoch 297/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6889 - val_loss: 0.6832
# Epoch 298/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6890 - val_loss: 0.6831
# Epoch 299/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6890 - val_loss: 0.6831
# Epoch 300/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6889 - val_loss: 0.6833
# Epoch 301/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6889 - val_loss: 0.6831
# Epoch 302/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6889 - val_loss: 0.6832
# Epoch 303/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6890 - val_loss: 0.6833
# Epoch 304/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6889 - val_loss: 0.6831
# Epoch 305/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6889 - val_loss: 0.6830
# Epoch 306/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6890 - val_loss: 0.6831
# Epoch 307/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6889 - val_loss: 0.6831
# Epoch 308/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6888 - val_loss: 0.6830
# Epoch 309/500
# 44/44 [==============================] - 19s 426ms/step - loss: 0.6888 - val_loss: 0.6830
# Epoch 310/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6889 - val_loss: 0.6836
# Epoch 311/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6890 - val_loss: 0.6830
# Epoch 312/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6888 - val_loss: 0.6830
# Epoch 313/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6888 - val_loss: 0.6830
# Epoch 314/500
# 44/44 [==============================] - 19s 427ms/step - loss: 0.6888 - val_loss: 0.6830
# Epoch 315/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6887 - val_loss: 0.6829
# Epoch 316/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6888 - val_loss: 0.6832
# Epoch 317/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6888 - val_loss: 0.6829
# Epoch 318/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6888 - val_loss: 0.6830
# Epoch 319/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6887 - val_loss: 0.6829
# Epoch 320/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6887 - val_loss: 0.6829
# Epoch 321/500
# 44/44 [==============================] - 19s 429ms/step - loss: 0.6889 - val_loss: 0.6830
# Epoch 322/500
# 44/44 [==============================] - 19s 430ms/step - loss: 0.6887 - val_loss: 0.6831
# Epoch 323/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6887 - val_loss: 0.6829
# Epoch 324/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6887 - val_loss: 0.6829
# Epoch 325/500
# 44/44 [==============================] - 19s 428ms/step - loss: 0.6888 - val_loss: 0.6831

# %%
#Plot Loss and Validation Loss

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %%
#Save the trained model
conv_autoencoder.save("h5_model.h5")

# %%
#Load the trained model
conv_autoencoder = keras.models.load_model("h5_model.h5")

# %% [markdown]
# # Compress and Decompress the Input

# %%
#Submit the Test Dataset to the Trained Autoencoder
x_test_pred = conv_autoencoder.predict(X_test_scaled)

#Reshape the Output
x_test_pred = x_test_pred.reshape((-1, x_test_pred.shape[1], x_test_pred.shape[2]))

# %% [markdown]
# # Calculate the Mean Average Error for Reconstruction

# %%
train_mae_loss = np.mean(np.abs(x_test_pred - X_test_scaled.reshape((-1, X_test_scaled.shape[1], X_test_scaled.shape[2]))), axis=None)

print("Mean reconstruction error: ", train_mae_loss)
# Out:
# Mean reconstruction error:  0.42215854

# %% [markdown]
# # Unscale Data

# %%
X_test_unscaled = []

for elem in x_test_pred:  
    X_test_unscaled.append(scaler_test.inverse_transform(elem))

X_test_unscaled = np.stack(X_test_unscaled)

# %% [markdown]
# # Pad to original size

# %%
X_test_unscaled_pad = []

for elem in X_test_unscaled:  
    X_test_unscaled_pad.append(np.pad(elem, ((1, 0), (1, 0)), 'constant'))

X_test_unscaled_pad = np.stack(X_test_unscaled_pad)

# %% [markdown]
# # Reconstruct Audio

# %%
 #Calculate the inverse STFT using the Griffin-Lim method that uses only the absolute value of STFT

reconstructed_test_griffinlim = []

for elem in X_test_unscaled_pad:
    reconstructed_test_griffinlim.append(librosa.griffinlim(elem))

# %% [markdown]
# # Pesq Metric Calculation

# %%
pesq_test_griffin = []

for x, y in zip(audio_inputs_test, reconstructed_test_griffinlim):
     pesq_test_griffin.append(pesq(16000, x, y, 'wb'))

pesq_test_griffin = np.stack(pesq_test_griffin)

# %%
pesq_test_griffin.mean()
# Out:
# 1.0537065089928535
